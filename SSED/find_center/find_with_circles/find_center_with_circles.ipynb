# %%
from find_center_with_circles import find_center
from plot_xy import plot_xy

# Paths to the files
h5_file_path = '/home/buster/UOX1/UOX1_min_10/UOX1_min_10.h5'
mask_path = '/home/buster/mask/pxmask.h5'
# selected_indices = list(range(0, 6700,1000))
selected_indices = [1200] 
# selected_indices = None

# Call the main processing function
find_center(h5_file_path, mask_path, selected_indices=selected_indices, plot=True, verbose=True)
# plot_xy(h5_file_path)
# Out:
# Processing image 1000...
# Processing image 0...
# Processing image 2000...
# Processing image 3000...
# Processing image 4000...
#
# Processing image 5000...
#
#
#
# Processing image 6000...
#
#
# Could not fit circle in bin 0.30 ± 0.03: RANSAC fitting failed: `min_samples` must be in range (0, 1)
# Could not fit circle in bin 0.30 ± 0.03: RANSAC fitting failed: `min_samples` must be in range (0, 1)
# Could not fit circle in bin 0.50 ± 0.03: RANSAC fitting failed: `min_samples` must be in range (0, 1)
# Could not fit circle in bin 0.50 ± 0.03: RANSAC fitting failed: `min_samples` must be in range (0, 1)
# Could not fit circle in bin 0.70 ± 0.03: RANSAC fitting failed: `min_samples` must be in range (0, 1)
# Could not fit circle in bin 0.30 ± 0.03: RANSAC fitting failed: `min_samples` must be in range (0, 1)
# ...
